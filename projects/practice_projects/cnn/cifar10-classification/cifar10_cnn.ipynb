# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()


# model = Sequential()
# model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=x_train.shape[1:]))
# model.add(Conv2D(32, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(num_classes, activation='softmax'))

# model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model4.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 52s - loss: 1.9738 - acc: 0.2882 - val_loss: 1.6981 - val_acc: 0.4066
#
# Epoch 00001: val_loss improved from inf to 1.69806, saving model to model4.weights.best.hdf5
# Epoch 2/100
#  - 52s - loss: 1.6792 - acc: 0.3976 - val_loss: 1.5387 - val_acc: 0.4632
#
# Epoch 00002: val_loss improved from 1.69806 to 1.53872, saving model to model4.weights.best.hdf5
# Epoch 3/100
#  - 53s - loss: 1.5569 - acc: 0.4385 - val_loss: 1.4485 - val_acc: 0.4896
#
# Epoch 00003: val_loss improved from 1.53872 to 1.44849, saving model to model4.weights.best.hdf5
# Epoch 4/100
#  - 55s - loss: 1.4813 - acc: 0.4676 - val_loss: 1.3785 - val_acc: 0.5128
#
# Epoch 00004: val_loss improved from 1.44849 to 1.37852, saving model to model4.weights.best.hdf5
# Epoch 5/100
#  - 53s - loss: 1.4212 - acc: 0.4894 - val_loss: 1.3273 - val_acc: 0.5356
#
# Epoch 00005: val_loss improved from 1.37852 to 1.32729, saving model to model4.weights.best.hdf5
# Epoch 6/100
#  - 53s - loss: 1.3744 - acc: 0.5080 - val_loss: 1.3698 - val_acc: 0.5286
#
# Epoch 00006: val_loss did not improve from 1.32729
# Epoch 7/100
#  - 56s - loss: 1.3379 - acc: 0.5237 - val_loss: 1.2442 - val_acc: 0.5612
#
# Epoch 00007: val_loss improved from 1.32729 to 1.24419, saving model to model4.weights.best.hdf5
# Epoch 8/100
#  - 54s - loss: 1.3024 - acc: 0.5339 - val_loss: 1.2245 - val_acc: 0.5624
#
# Epoch 00008: val_loss improved from 1.24419 to 1.22448, saving model to model4.weights.best.hdf5
# Epoch 9/100
#  - 55s - loss: 1.2735 - acc: 0.5500 - val_loss: 1.2214 - val_acc: 0.5618
#
# Epoch 00009: val_loss improved from 1.22448 to 1.22138, saving model to model4.weights.best.hdf5
# Epoch 10/100
#  - 55s - loss: 1.2502 - acc: 0.5552 - val_loss: 1.2156 - val_acc: 0.5750
#
# Epoch 00010: val_loss improved from 1.22138 to 1.21558, saving model to model4.weights.best.hdf5
# Epoch 11/100
#  - 55s - loss: 1.2247 - acc: 0.5630 - val_loss: 1.1747 - val_acc: 0.5830
#
# Epoch 00011: val_loss improved from 1.21558 to 1.17473, saving model to model4.weights.best.hdf5
# Epoch 12/100
#  - 55s - loss: 1.2025 - acc: 0.5749 - val_loss: 1.1495 - val_acc: 0.5982
#
# Epoch 00012: val_loss improved from 1.17473 to 1.14954, saving model to model4.weights.best.hdf5
# Epoch 13/100
#  - 54s - loss: 1.1837 - acc: 0.5807 - val_loss: 1.1335 - val_acc: 0.6020
#
# Epoch 00013: val_loss improved from 1.14954 to 1.13353, saving model to model4.weights.best.hdf5
# Epoch 14/100
#  - 56s - loss: 1.1690 - acc: 0.5862 - val_loss: 1.1990 - val_acc: 0.5818
#
# Epoch 00014: val_loss did not improve from 1.13353
# Epoch 15/100
#  - 54s - loss: 1.1486 - acc: 0.5946 - val_loss: 1.0880 - val_acc: 0.6162
#
# Epoch 00015: val_loss improved from 1.13353 to 1.08796, saving model to model4.weights.best.hdf5
# Epoch 16/100
#  - 56s - loss: 1.1334 - acc: 0.5998 - val_loss: 1.1129 - val_acc: 0.6080
#
# Epoch 00016: val_loss did not improve from 1.08796
# Epoch 17/100
#  - 53s - loss: 1.1212 - acc: 0.6055 - val_loss: 1.0813 - val_acc: 0.6212
#
# Epoch 00017: val_loss improved from 1.08796 to 1.08131, saving model to model4.weights.best.hdf5
# Epoch 18/100
#  - 54s - loss: 1.1039 - acc: 0.6124 - val_loss: 1.0439 - val_acc: 0.6354
#
# Epoch 00018: val_loss improved from 1.08131 to 1.04389, saving model to model4.weights.best.hdf5
# Epoch 19/100
#  - 57s - loss: 1.0889 - acc: 0.6169 - val_loss: 1.0388 - val_acc: 0.6326
#
# Epoch 00019: val_loss improved from 1.04389 to 1.03885, saving model to model4.weights.best.hdf5
# Epoch 20/100
#  - 53s - loss: 1.0816 - acc: 0.6200 - val_loss: 1.0475 - val_acc: 0.6358
#
# Epoch 00020: val_loss did not improve from 1.03885
# Epoch 21/100
#  - 55s - loss: 1.0693 - acc: 0.6236 - val_loss: 1.0256 - val_acc: 0.6350
#
# Epoch 00021: val_loss improved from 1.03885 to 1.02559, saving model to model4.weights.best.hdf5
# Epoch 22/100
#  - 55s - loss: 1.0576 - acc: 0.6292 - val_loss: 1.0087 - val_acc: 0.6436
#
# Epoch 00022: val_loss improved from 1.02559 to 1.00874, saving model to model4.weights.best.hdf5
# Epoch 23/100
#  - 54s - loss: 1.0481 - acc: 0.6312 - val_loss: 1.0189 - val_acc: 0.6374
#
# Epoch 00023: val_loss did not improve from 1.00874
# Epoch 24/100
#  - 54s - loss: 1.0391 - acc: 0.6369 - val_loss: 1.1052 - val_acc: 0.6100
#
# Epoch 00024: val_loss did not improve from 1.00874
# Epoch 25/100
#  - 56s - loss: 1.0320 - acc: 0.6384 - val_loss: 0.9812 - val_acc: 0.6592
#
# Epoch 00025: val_loss improved from 1.00874 to 0.98119, saving model to model4.weights.best.hdf5
# Epoch 26/100
#  - 58s - loss: 1.0208 - acc: 0.6404 - val_loss: 0.9916 - val_acc: 0.6534
#
# Epoch 00026: val_loss did not improve from 0.98119
# Epoch 27/100
#  - 57s - loss: 1.0122 - acc: 0.6465 - val_loss: 0.9734 - val_acc: 0.6476
#
# Epoch 00027: val_loss improved from 0.98119 to 0.97343, saving model to model4.weights.best.hdf5
# Epoch 28/100
#  - 57s - loss: 1.0061 - acc: 0.6477 - val_loss: 0.9745 - val_acc: 0.6478
#
# Epoch 00028: val_loss did not improve from 0.97343
# Epoch 29/100
#  - 58s - loss: 0.9997 - acc: 0.6508 - val_loss: 0.9891 - val_acc: 0.6434
#
# Epoch 00029: val_loss did not improve from 0.97343
# Epoch 30/100
#  - 57s - loss: 0.9916 - acc: 0.6525 - val_loss: 1.0124 - val_acc: 0.6518
#
# Epoch 00030: val_loss did not improve from 0.97343
# Epoch 31/100
#  - 55s - loss: 0.9863 - acc: 0.6560 - val_loss: 0.9463 - val_acc: 0.6676
#
# Epoch 00031: val_loss improved from 0.97343 to 0.94625, saving model to model4.weights.best.hdf5
# Epoch 32/100
#  - 56s - loss: 0.9772 - acc: 0.6586 - val_loss: 0.9328 - val_acc: 0.6666
#
# Epoch 00032: val_loss improved from 0.94625 to 0.93281, saving model to model4.weights.best.hdf5
# Epoch 33/100
#  - 56s - loss: 0.9737 - acc: 0.6614 - val_loss: 1.0422 - val_acc: 0.6478
#
# Epoch 00033: val_loss did not improve from 0.93281
# Epoch 34/100
#  - 55s - loss: 0.9643 - acc: 0.6656 - val_loss: 0.9511 - val_acc: 0.6652
#
# Epoch 00034: val_loss did not improve from 0.93281
# Epoch 35/100
#  - 56s - loss: 0.9647 - acc: 0.6659 - val_loss: 0.9645 - val_acc: 0.6672
#
# Epoch 00035: val_loss did not improve from 0.93281
# Epoch 36/100
#  - 54s - loss: 0.9531 - acc: 0.6690 - val_loss: 0.9350 - val_acc: 0.6714
#
# Epoch 00036: val_loss did not improve from 0.93281
# Epoch 37/100
#  - 54s - loss: 0.9533 - acc: 0.6679 - val_loss: 0.9246 - val_acc: 0.6734
#
# Epoch 00037: val_loss improved from 0.93281 to 0.92464, saving model to model4.weights.best.hdf5
# Epoch 38/100
#  - 56s - loss: 0.9488 - acc: 0.6708 - val_loss: 0.9204 - val_acc: 0.6706
#
# Epoch 00038: val_loss improved from 0.92464 to 0.92042, saving model to model4.weights.best.hdf5
# Epoch 39/100
#  - 54s - loss: 0.9405 - acc: 0.6747 - val_loss: 0.9193 - val_acc: 0.6830
#
# Epoch 00039: val_loss improved from 0.92042 to 0.91930, saving model to model4.weights.best.hdf5
# Epoch 40/100
#  - 53s - loss: 0.9426 - acc: 0.6752 - val_loss: 0.9123 - val_acc: 0.6822
#
# Epoch 00040: val_loss improved from 0.91930 to 0.91228, saving model to model4.weights.best.hdf5
# Epoch 41/100
#  - 54s - loss: 0.9348 - acc: 0.6789 - val_loss: 0.9404 - val_acc: 0.6710
#
# Epoch 00041: val_loss did not improve from 0.91228
# Epoch 42/100
#  - 54s - loss: 0.9337 - acc: 0.6770 - val_loss: 0.9120 - val_acc: 0.6788
#
# Epoch 00042: val_loss improved from 0.91228 to 0.91197, saving model to model4.weights.best.hdf5
# Epoch 43/100
#  - 54s - loss: 0.9323 - acc: 0.6773 - val_loss: 0.9400 - val_acc: 0.6782
#
# Epoch 00043: val_loss did not improve from 0.91197
# Epoch 44/100
#  - 54s - loss: 0.9271 - acc: 0.6815 - val_loss: 0.8911 - val_acc: 0.6868
#
# Epoch 00044: val_loss improved from 0.91197 to 0.89105, saving model to model4.weights.best.hdf5
# Epoch 45/100
#  - 54s - loss: 0.9278 - acc: 0.6804 - val_loss: 0.9122 - val_acc: 0.6858
#
# Epoch 00045: val_loss did not improve from 0.89105
# Epoch 46/100
#  - 54s - loss: 0.9246 - acc: 0.6840 - val_loss: 0.9298 - val_acc: 0.6842
#
# Epoch 00046: val_loss did not improve from 0.89105
# Epoch 47/100
#  - 54s - loss: 0.9225 - acc: 0.6821 - val_loss: 0.9241 - val_acc: 0.6788
#
# Epoch 00047: val_loss did not improve from 0.89105
# Epoch 48/100
#  - 54s - loss: 0.9223 - acc: 0.6829 - val_loss: 0.9181 - val_acc: 0.6848
#
# Epoch 00048: val_loss did not improve from 0.89105
# Epoch 49/100
#  - 55s - loss: 0.9252 - acc: 0.6841 - val_loss: 0.9946 - val_acc: 0.6546
#
# Epoch 00049: val_loss did not improve from 0.89105
# Epoch 50/100
#  - 54s - loss: 0.9182 - acc: 0.6872 - val_loss: 0.9123 - val_acc: 0.6846
#
# Epoch 00050: val_loss did not improve from 0.89105
# Epoch 51/100
#  - 54s - loss: 0.9207 - acc: 0.6848 - val_loss: 0.9938 - val_acc: 0.6650
#
# Epoch 00051: val_loss did not improve from 0.89105
# Epoch 52/100
#  - 54s - loss: 0.9199 - acc: 0.6863 - val_loss: 0.8894 - val_acc: 0.6894
#
# Epoch 00052: val_loss improved from 0.89105 to 0.88944, saving model to model4.weights.best.hdf5
# Epoch 53/100
#  - 54s - loss: 0.9183 - acc: 0.6864 - val_loss: 0.9458 - val_acc: 0.6786
#
# Epoch 00053: val_loss did not improve from 0.88944
# Epoch 54/100
#  - 53s - loss: 0.9182 - acc: 0.6879 - val_loss: 0.9476 - val_acc: 0.6778
#
# Epoch 00054: val_loss did not improve from 0.88944
# Epoch 55/100
#  - 54s - loss: 0.9194 - acc: 0.6883 - val_loss: 0.9204 - val_acc: 0.6886
#
# Epoch 00055: val_loss did not improve from 0.88944
# Epoch 56/100
#  - 55s - loss: 0.9197 - acc: 0.6873 - val_loss: 0.9343 - val_acc: 0.6786
#
# Epoch 00056: val_loss did not improve from 0.88944
# Epoch 57/100
#  - 54s - loss: 0.9222 - acc: 0.6869 - val_loss: 0.8859 - val_acc: 0.6960
#
# Epoch 00057: val_loss improved from 0.88944 to 0.88590, saving model to model4.weights.best.hdf5
# Epoch 58/100
#  - 55s - loss: 0.9196 - acc: 0.6894 - val_loss: 0.9163 - val_acc: 0.6832
#
# Epoch 00058: val_loss did not improve from 0.88590
# Epoch 59/100
#  - 55s - loss: 0.9176 - acc: 0.6891 - val_loss: 0.8953 - val_acc: 0.6972
#
# Epoch 00059: val_loss did not improve from 0.88590
# Epoch 60/100
#  - 55s - loss: 0.9124 - acc: 0.6913 - val_loss: 0.9207 - val_acc: 0.6848
#
# Epoch 00060: val_loss did not improve from 0.88590
# Epoch 61/100
#  - 55s - loss: 0.9200 - acc: 0.6879 - val_loss: 0.8999 - val_acc: 0.6882
#
# Epoch 00061: val_loss did not improve from 0.88590
# Epoch 62/100
#  - 55s - loss: 0.9166 - acc: 0.6898 - val_loss: 0.9306 - val_acc: 0.6894
#
# Epoch 00062: val_loss did not improve from 0.88590
# Epoch 63/100
#  - 55s - loss: 0.9159 - acc: 0.6926 - val_loss: 0.8882 - val_acc: 0.7014
#
# Epoch 00063: val_loss did not improve from 0.88590
# Epoch 64/100
#  - 55s - loss: 0.9242 - acc: 0.6889 - val_loss: 0.9405 - val_acc: 0.6974
#
# Epoch 00064: val_loss did not improve from 0.88590
# Epoch 65/100
#  - 55s - loss: 0.9215 - acc: 0.6903 - val_loss: 0.9283 - val_acc: 0.6962
#
# Epoch 00065: val_loss did not improve from 0.88590
# Epoch 66/100
#  - 54s - loss: 0.9250 - acc: 0.6894 - val_loss: 0.9833 - val_acc: 0.6932
#
# Epoch 00066: val_loss did not improve from 0.88590
# Epoch 67/100
#  - 55s - loss: 0.9233 - acc: 0.6890 - val_loss: 0.8932 - val_acc: 0.6984
#
# Epoch 00067: val_loss did not improve from 0.88590
# Epoch 68/100
#  - 55s - loss: 0.9234 - acc: 0.6870 - val_loss: 0.9247 - val_acc: 0.6804
#
# Epoch 00068: val_loss did not improve from 0.88590
# Epoch 69/100
#  - 54s - loss: 0.9287 - acc: 0.6868 - val_loss: 0.9054 - val_acc: 0.6982
#
# Epoch 00069: val_loss did not improve from 0.88590
# Epoch 70/100
#  - 54s - loss: 0.9256 - acc: 0.6901 - val_loss: 0.9309 - val_acc: 0.6972
#
# Epoch 00070: val_loss did not improve from 0.88590
# Epoch 71/100
#  - 55s - loss: 0.9359 - acc: 0.6880 - val_loss: 1.0000 - val_acc: 0.6714
#
# Epoch 00071: val_loss did not improve from 0.88590
# Epoch 72/100
#  - 55s - loss: 0.9313 - acc: 0.6882 - val_loss: 0.9732 - val_acc: 0.6782
#
# Epoch 00072: val_loss did not improve from 0.88590
# Epoch 73/100
#  - 55s - loss: 0.9266 - acc: 0.6892 - val_loss: 0.9124 - val_acc: 0.6978
#
# Epoch 00073: val_loss did not improve from 0.88590
# Epoch 74/100
#  - 55s - loss: 0.9363 - acc: 0.6873 - val_loss: 0.9485 - val_acc: 0.6886
#
# Epoch 00074: val_loss did not improve from 0.88590
# Epoch 75/100
#  - 55s - loss: 0.9367 - acc: 0.6880 - val_loss: 0.9096 - val_acc: 0.6968
#
# Epoch 00075: val_loss did not improve from 0.88590
# Epoch 76/100
#  - 55s - loss: 0.9362 - acc: 0.6871 - val_loss: 0.9099 - val_acc: 0.6976
#
# Epoch 00076: val_loss did not improve from 0.88590
# Epoch 77/100
#  - 55s - loss: 0.9413 - acc: 0.6867 - val_loss: 0.9647 - val_acc: 0.6862
#
# Epoch 00077: val_loss did not improve from 0.88590
# Epoch 78/100
#  - 55s - loss: 0.9419 - acc: 0.6862 - val_loss: 0.9047 - val_acc: 0.6962
#
# Epoch 00078: val_loss did not improve from 0.88590
# Epoch 79/100
#  - 55s - loss: 0.9452 - acc: 0.6864 - val_loss: 0.9926 - val_acc: 0.6892
#
# Epoch 00079: val_loss did not improve from 0.88590
# Epoch 80/100
#  - 55s - loss: 0.9432 - acc: 0.6858 - val_loss: 0.9822 - val_acc: 0.6874
#
# Epoch 00080: val_loss did not improve from 0.88590
# Epoch 81/100
#  - 55s - loss: 0.9513 - acc: 0.6819 - val_loss: 0.9480 - val_acc: 0.6920
#
# Epoch 00081: val_loss did not improve from 0.88590
# Epoch 82/100
#  - 55s - loss: 0.9467 - acc: 0.6863 - val_loss: 0.9855 - val_acc: 0.6688
#
# Epoch 00082: val_loss did not improve from 0.88590
# Epoch 83/100
#  - 54s - loss: 0.9500 - acc: 0.6842 - val_loss: 0.9739 - val_acc: 0.6912
#
# Epoch 00083: val_loss did not improve from 0.88590
# Epoch 84/100
#  - 55s - loss: 0.9542 - acc: 0.6816 - val_loss: 0.9300 - val_acc: 0.6936
#
# Epoch 00084: val_loss did not improve from 0.88590
# Epoch 85/100
#  - 55s - loss: 0.9508 - acc: 0.6853 - val_loss: 0.9622 - val_acc: 0.6828
#
# Epoch 00085: val_loss did not improve from 0.88590
# Epoch 86/100
#  - 55s - loss: 0.9500 - acc: 0.6835 - val_loss: 0.9545 - val_acc: 0.6890
#
# Epoch 00086: val_loss did not improve from 0.88590
# Epoch 87/100
#  - 55s - loss: 0.9551 - acc: 0.6830 - val_loss: 0.9441 - val_acc: 0.6892
#
# Epoch 00087: val_loss did not improve from 0.88590
# Epoch 88/100
#  - 54s - loss: 0.9629 - acc: 0.6799 - val_loss: 0.8908 - val_acc: 0.7070
#
# Epoch 00088: val_loss did not improve from 0.88590
# Epoch 89/100
#  - 54s - loss: 0.9561 - acc: 0.6834 - val_loss: 0.9460 - val_acc: 0.6922
#
# Epoch 00089: val_loss did not improve from 0.88590
# Epoch 90/100
#  - 54s - loss: 0.9536 - acc: 0.6844 - val_loss: 0.9157 - val_acc: 0.6940
#
# Epoch 00090: val_loss did not improve from 0.88590
# Epoch 91/100
#  - 55s - loss: 0.9604 - acc: 0.6827 - val_loss: 0.9081 - val_acc: 0.7048
#
# Epoch 00091: val_loss did not improve from 0.88590
# Epoch 92/100
#  - 54s - loss: 0.9631 - acc: 0.6812 - val_loss: 0.9185 - val_acc: 0.6980
#
# Epoch 00092: val_loss did not improve from 0.88590
# Epoch 93/100
#  - 55s - loss: 0.9719 - acc: 0.6788 - val_loss: 0.9351 - val_acc: 0.6922
#
# Epoch 00093: val_loss did not improve from 0.88590
# Epoch 94/100
#  - 54s - loss: 0.9709 - acc: 0.6782 - val_loss: 0.9772 - val_acc: 0.6902
#
# Epoch 00094: val_loss did not improve from 0.88590
# Epoch 95/100
#  - 55s - loss: 0.9685 - acc: 0.6763 - val_loss: 1.0519 - val_acc: 0.6738
#
# Epoch 00095: val_loss did not improve from 0.88590
# Epoch 96/100
#  - 55s - loss: 0.9691 - acc: 0.6793 - val_loss: 0.9308 - val_acc: 0.6942
#
# Epoch 00096: val_loss did not improve from 0.88590
# Epoch 97/100
#  - 55s - loss: 0.9763 - acc: 0.6756 - val_loss: 0.9893 - val_acc: 0.6822
#
# Epoch 00097: val_loss did not improve from 0.88590
# Epoch 98/100
#  - 55s - loss: 0.9829 - acc: 0.6766 - val_loss: 0.9699 - val_acc: 0.6792
#
# Epoch 00098: val_loss did not improve from 0.88590
# Epoch 99/100
#  - 55s - loss: 0.9785 - acc: 0.6730 - val_loss: 1.1133 - val_acc: 0.6622
#
# Epoch 00099: val_loss did not improve from 0.88590
# Epoch 100/100
#  - 55s - loss: 0.9808 - acc: 0.6763 - val_loss: 0.9547 - val_acc: 0.6878
#
# Epoch 00100: val_loss did not improve from 0.88590

# %%
# from https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/

# summarize history for accuracy
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model4.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6959

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
